# %%
# !pip install pymzml boto3
# !pip install pyarrow
# !pip install fastparquet
# Out:
# Requirement already satisfied: pymzml in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.5.11)
# Requirement already satisfied: boto3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.40.41)
# Requirement already satisfied: numpy>=1.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from pymzml) (2.2.5)
# Requirement already satisfied: regex in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pymzml) (2025.9.18)
# Requirement already satisfied: botocore<1.41.0,>=1.40.41 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3) (1.40.41)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.41->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.41->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.41->boto3) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: pyarrow in /usr/local/python/3.12.1/lib/python3.12/site-packages (21.0.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (2.2.5)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: fsspec in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2024.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.6 MB/s eta 0:00:00
# Downloading cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 43.8 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [fastparquet]
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pymzml
import gzip
import os
import zipfile
import pandas as pd
import numpy as np
import boto3
from botocore import UNSIGNED
from botocore.client import Config

# %%
s3_client = boto3.client('s3', config=Config(signature_version=UNSIGNED))

bucket_name = 'nasa-osdr'

base_path = 'OSD-832/version-2/metabolomics/'

temp_dir = '/tmp/osd_data'
os.makedirs(temp_dir, exist_ok=True)

# %%
# Characterizing a single file for debugging

key = base_path + 'GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz'
filename = os.path.basename(key)
local_filepath = os.path.join(temp_dir, filename)

print(f"Downloading {filename} for inspection...")
s3_client.download_file(bucket_name, key, local_filepath)

print(f"Inspecting {filename}...")
spectra = pymzml.run.Reader(local_filepath)

spectrum_to_inspect = next(iter(spectra))
attributes = [attr for attr in dir(spectrum_to_inspect) if not attr.startswith('_')]
print(f"\nAttributes: {attributes}")
print(f"\nMS Level: {spectrum_to_inspect.ms_level}")

if len(spectrum_to_inspect.i) > 0:
    highest_mz, highest_intensity = max(zip(spectrum_to_inspect.mz, spectrum_to_inspect.i), key=lambda item: item[1])
    print(f"Highest Peak (m/z, Intensity): ({highest_mz}, {highest_intensity})")
else:
    print("Highest Peak (m/z, Intensity): (Spectrum is empty)")

print(f"Total number of peaks in this spectrum: {len(spectrum_to_inspect.i)}")
print(f"Scan Time (Retention Time): {spectrum_to_inspect.scan_time_in_minutes()} minutes")
print(f"Number of spectra found: {len(list(spectra))}")
print(spectra)

os.remove(local_filepath)
# Out:
# Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz for inspection...
# Inspecting GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz...
#
# Attributes: ['ID', 'TIC', 'centroidedPeaks', 'deprecation_warning', 'element', 'estimatedNoiseLevel', 'estimated_noise_level', 'extremeValues', 'extreme_values', 'get', 'get_all_arrays_in_spec', 'get_array', 'get_element_by_name', 'get_element_by_path', 'get_tims_tof_ion_mobility', 'hasOverlappingPeak', 'hasPeak', 'has_overlapping_peak', 'has_peak', 'highestPeaks', 'highest_peaks', 'i', 'id_dict', 'index', 'internal_precision', 'measured_precision', 'ms_level', 'mz', 'noise_level_estimate', 'ns', 'obo_translator', 'peaks', 'ppm2abs', 'precursors', 'reduce', 'removeNoise', 'remove_noise', 'remove_precursor_peak', 'reprofiled', 'scan_time', 'scan_time_in_minutes', 'selected_precursors', 'set_peaks', 'similarityTo', 'similarity_to', 't_mz_set', 'to_string', 'transformMZ', 'transform_mz', 'transformed_mz_with_error', 'transformed_peaks']
#
# MS Level: 1
# Highest Peak (m/z, Intensity): (141.95888723059318, 17880.0)
# Total number of peaks in this spectrum: 2347
# Scan Time (Retention Time): 0.002083333333 minutes
# Number of spectra found: 17539
# <pymzml.run.Reader object at 0x74b421e72780>

# %%
results = []
metadata_key = 'OSD-832/version-2/metadata/OSD-832_metadata_OSD-832-ISA.zip'
local_zip_path = os.path.join(temp_dir, 'metadata.zip')

try:
    print(f"Downloading {os.path.basename(metadata_key)}...")
    s3_client.download_file(bucket_name, metadata_key, local_zip_path)
    print("Download complete.")

    print("Unzipping metadata file...")
    with zipfile.ZipFile(local_zip_path, 'r') as zip_ref:
        zip_ref.extractall(temp_dir)
        list_of_files = zip_ref.namelist()
        print(f"\nList of zip files:")
        print(f"{list_of_files}\n")
    print("Unzip complete.")

    unzipped_files = os.listdir(temp_dir)
    meta_files = [f for f in unzipped_files if f.startswith('s_') and f.endswith('.txt')]

    if meta_files:
        meta_filename = meta_files[0]
        local_metadata_path = os.path.join(temp_dir, meta_filename)
        print(f"Found sample metadata file: {meta_filename}")

        df_meta = pd.read_csv(local_metadata_path, sep='\t')

        print(df_meta.columns.tolist())
        print("\nSuccessfully loaded metadata. Displaying first 5 rows:")
        display(df_meta.head())
        
    else:
        print("Error: Could not load sample metadata file.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Downloading OSD-832_metadata_OSD-832-ISA.zip...
# Download complete.
# Unzipping metadata file...
#
# List of zip files:
# ['i_Investigation.txt', 's_OSD-832.txt', 'a_OSD-832_metabolite-profiling_mass-spectrometry_TripleTOF 5600(AB Sciex).txt']
#
# Unzip complete.
# Found sample metadata file: s_OSD-832.txt
# ['Source Name', 'Sample Name', 'Characteristics[Organism]', 'Term Source REF', 'Term Accession Number', 'Characteristics[Strain]', 'Term Source REF.1', 'Term Accession Number.1', 'Characteristics[Animal Source]', 'Characteristics[Genotype]', 'Term Source REF.2', 'Term Accession Number.2', 'Characteristics[Sex]', 'Term Source REF.3', 'Term Accession Number.3', 'Factor Value[Hindlimb Unloading]', 'Factor Value[Ionizing Radiation]', 'Term Source REF.4', 'Term Accession Number.4', 'Characteristics[Age at Irradiation]', 'Unit', 'Term Source REF.5', 'Term Accession Number.5', 'Characteristics[Material Type]', 'Term Source REF.6', 'Term Accession Number.6', 'Protocol REF', 'Parameter Value[Diet]', 'Parameter Value[Feeding Schedule]', 'Parameter Value[Enrichment material]', 'Parameter Value[light cycle]', 'Parameter Value[Hindlimb Unloading Duration]', 'Unit.1', 'Term Source REF.7', 'Term Accession Number.7', 'Protocol REF.1', 'Parameter Value[particle charge]', 'Term Source REF.8', 'Term Accession Number.8', 'Parameter Value[absorbed radiation dose]', 'Unit.2', 'Term Source REF.9', 'Term Accession Number.9', 'Parameter Value[ionizing radiation energy]', 'Parameter Value[linear energy transfer]', 'Parameter Value[ionizing radiation categorized by source]', 'Term Source REF.10', 'Term Accession Number.10', 'Parameter Value[ionizing radiation device]', 'Term Source REF.11', 'Term Accession Number.11', 'Parameter Value[absorbed radiation dose rate]', 'Protocol REF.2', 'Parameter Value[Euthanasia Method]', 'Term Source REF.12', 'Term Accession Number.12', 'Parameter Value[Sample Storage Temperature]', 'Unit.3', 'Term Source REF.13', 'Term Accession Number.13']
#
# Successfully loaded metadata. Displaying first 5 rows:
#   Source Name  Sample Name Characteristics[Organism] Term Source REF  \
# 0        9394  9394 plasma         Rattus norvegicus       NCBITAXON
# 1        9395  9395 plasma         Rattus norvegicus       NCBITAXON
# 2        9396  9396 plasma         Rattus norvegicus       NCBITAXON
# 3        9397  9397 plasma         Rattus norvegicus       NCBITAXON
# 4        9398  9398 plasma         Rattus norvegicus       NCBITAXON
#
#                                Term Accession Number Characteristics[Strain]  \
# 0  http://purl.bioontology.org/ontology/NCBITAXON...            WAG/Rij/Cmcr
# 1  http://purl.bioontology.org/ontology/NCBITAXON...            WAG/Rij/Cmcr
# 2  http://purl.bioontology.org/ontology/NCBITAXON...            WAG/Rij/Cmcr
# 3  http://purl.bioontology.org/ontology/NCBITAXON...            WAG/Rij/Cmcr
# 4  http://purl.bioontology.org/ontology/NCBITAXON...            WAG/Rij/Cmcr
#
#   Term Source REF.1 Term Accession Number.1 Characteristics[Animal Source]  \
# 0               OSD  https://osdr.nasa.gov/   Medical College of Wisconsin
# 1               OSD  https://osdr.nasa.gov/   Medical College of Wisconsin
# 2               OSD  https://osdr.nasa.gov/   Medical College of Wisconsin
# 3               OSD  https://osdr.nasa.gov/   Medical College of Wisconsin
# 4               OSD  https://osdr.nasa.gov/   Medical College of Wisconsin
#
#   Characteristics[Genotype]  ...                    Term Accession Number.11  \
# 0                 Wild Type  ...  http://purl.obolibrary.org/obo/NCIT_C48660
# 1                 Wild Type  ...  http://purl.obolibrary.org/obo/NCIT_C48660
# 2                 Wild Type  ...  http://purl.obolibrary.org/obo/NCIT_C48660
# 3                 Wild Type  ...  http://purl.obolibrary.org/obo/NCIT_C48660
# 4                 Wild Type  ...  http://purl.obolibrary.org/obo/NCIT_C48660
#
#   Parameter Value[absorbed radiation dose rate]     Protocol REF.2  \
# 0                                Not Applicable  sample collection
# 1                                Not Applicable  sample collection
# 2                                Not Applicable  sample collection
# 3                                Not Applicable  sample collection
# 4                                Not Applicable  sample collection
#
#   Parameter Value[Euthanasia Method] Term Source REF.12  \
# 0                         Guillotine           SNOMEDCT
# 1                         Guillotine           SNOMEDCT
# 2                         Guillotine           SNOMEDCT
# 3                         Guillotine           SNOMEDCT
# 4                         Guillotine           SNOMEDCT
#
#                             Term Accession Number.12  \
# 0  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 1  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 2  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 3  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 4  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#   Parameter Value[Sample Storage Temperature]          Unit.3  \
# 0                                       -80.0  degree Celsius
# 1                                       -80.0  degree Celsius
# 2                                       -80.0  degree Celsius
# 3                                       -80.0  degree Celsius
# 4                                       -80.0  degree Celsius
#
#   Term Source REF.13                   Term Accession Number.13
# 0                 UO  http://purl.obolibrary.org/obo/UO_0000027
# 1                 UO  http://purl.obolibrary.org/obo/UO_0000027
# 2                 UO  http://purl.obolibrary.org/obo/UO_0000027
# 3                 UO  http://purl.obolibrary.org/obo/UO_0000027
# 4                 UO  http://purl.obolibrary.org/obo/UO_0000027
#
# [5 rows x 60 columns]

# %%
assay_files = [f for f in os.listdir(temp_dir) if f.startswith('a_') and f.endswith('.txt')]

if assay_files:
    assay_filename = assay_files[0]
    local_assay_path = os.path.join(temp_dir, assay_filename)
    print(f"Found assay file: {assay_filename}")

    df_assay = pd.read_csv(local_assay_path, sep='\t')
    
    print("\nDisplaying first 5 rows of the assay file:")
    display(df_assay.head())
else:
    print("Error: Could not load assay file.")
# Out:
# Found assay file: a_OSD-832_metabolite-profiling_mass-spectrometry_TripleTOF 5600(AB Sciex).txt
#
# Displaying first 5 rows of the assay file:
#    Sample Name Protocol REF  Parameter Value[Processed Amount]        Unit  \
# 0  9394 plasma   Extraction                              100.0  microliter
# 1  9395 plasma   Extraction                              100.0  microliter
# 2  9396 plasma   Extraction                              100.0  microliter
# 3  9397 plasma   Extraction                              100.0  microliter
# 4  9398 plasma   Extraction                              100.0  microliter
#
#   Term Source REF                      Term Accession Number Extract Name  \
# 0              UO  http://purl.obolibrary.org/obo/UO_0000101  9394 plasma
# 1              UO  http://purl.obolibrary.org/obo/UO_0000101  9395 plasma
# 2              UO  http://purl.obolibrary.org/obo/UO_0000101  9396 plasma
# 3              UO  http://purl.obolibrary.org/obo/UO_0000101  9397 plasma
# 4              UO  http://purl.obolibrary.org/obo/UO_0000101  9398 plasma
#
#       Protocol REF.1 Parameter Value[Instrument]  \
# 0  Mass Spectrometry     AB SCIEX TripleTOF 5600
# 1  Mass Spectrometry     AB SCIEX TripleTOF 5600
# 2  Mass Spectrometry     AB SCIEX TripleTOF 5600
# 3  Mass Spectrometry     AB SCIEX TripleTOF 5600
# 4  Mass Spectrometry     AB SCIEX TripleTOF 5600
#
#      Parameter Value[Ion Source]          Parameter Value[Analyzer]  \
# 0  electrospray ionization (ESI)  Quadrupole time-of-flight (Q-TOF)
# 1  electrospray ionization (ESI)  Quadrupole time-of-flight (Q-TOF)
# 2  electrospray ionization (ESI)  Quadrupole time-of-flight (Q-TOF)
# 3  electrospray ionization (ESI)  Quadrupole time-of-flight (Q-TOF)
# 4  electrospray ionization (ESI)  Quadrupole time-of-flight (Q-TOF)
#
#   MS Assay Name                             Raw Spectral Data File  \
# 0  metabolomics  GLDS-703_metabolomics_pos49.raw.zip, GLDS-703_...
# 1  metabolomics  GLDS-703_metabolomics_pos23.raw.zip, GLDS-703_...
# 2  metabolomics  GLDS-703_metabolomics_pos22.raw.zip, GLDS-703_...
# 3  metabolomics  GLDS-703_metabolomics_pos15.raw.zip, GLDS-703_...
# 4  metabolomics  GLDS-703_metabolomics_pos12.raw.zip, GLDS-703_...
#
#       Parameter Value[Raw Spectral Data File (mzML)]
# 0  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 1  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 2  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 3  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 4  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...

# %%
meta_subset = df_meta[['Sample Name', 'Factor Value[Ionizing Radiation]', 'Factor Value[Hindlimb Unloading]']]
assay_subset = df_assay[['Sample Name', 'Parameter Value[Raw Spectral Data File (mzML)]']]

df_combined = pd.merge(assay_subset, meta_subset, on='Sample Name')
df_combined['Parameter Value[Raw Spectral Data File (mzML)]'] = df_combined['Parameter Value[Raw Spectral Data File (mzML)]'].str.split(', ')
df_combined = df_combined.explode('Parameter Value[Raw Spectral Data File (mzML)]')

display(df_combined.head())
# Out:
#    Sample Name     Parameter Value[Raw Spectral Data File (mzML)]  \
# 0  9394 plasma  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 0  9394 plasma  GLDS-703_metabolomics_091920_Raber_Marek_Negat...
# 1  9395 plasma  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 1  9395 plasma  GLDS-703_metabolomics_091920_Raber_Marek_Negat...
# 2  9396 plasma  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
#
#   Factor Value[Ionizing Radiation] Factor Value[Hindlimb Unloading]
# 0                  sham-irradiated          Normally Loaded Control
# 0                  sham-irradiated          Normally Loaded Control
# 1                  sham-irradiated          Normally Loaded Control
# 1                  sham-irradiated          Normally Loaded Control
# 2                  sham-irradiated          Normally Loaded Control

# %%
s3_file_keys = []
print(f"Finding all files in s3://{bucket_name}/{base_path}...")
paginator = s3_client.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=bucket_name, Prefix=base_path)
# Out:
# Finding all files in s3://nasa-osdr/OSD-832/version-2/metabolomics/...

# %%
first_page = next(iter(pages))

print(f"\nThe 'page' object: {type(first_page)}")
print(f"Keys: {list(first_page.keys())}")

if 'Contents' in first_page:
    contents = first_page['Contents']
    print(f"\nThe 'Contents' key holds: {type(contents)}")

    if contents:
        first_obj = contents[0]
        print(f"\nEach item inside 'Contents': {type(first_obj)}")
        
        print(f"\nThe keys for a single file object: {list(first_obj.keys())}")

        print(f"\nThe 'Key' for the first file: '{first_obj['Key']}'")
# Out:
# The 'page' object: <class 'dict'>
# Keys: ['ResponseMetadata', 'IsTruncated', 'Contents', 'Name', 'Prefix', 'MaxKeys', 'EncodingType', 'KeyCount']
#
# The 'Contents' key holds: <class 'list'>
#
# Each item inside 'Contents': <class 'dict'>
#
# The keys for a single file object: ['Key', 'LastModified', 'ETag', 'ChecksumAlgorithm', 'ChecksumType', 'Size', 'StorageClass']
#
# [Step 5] The 'Key' for the first file: 'OSD-832/version-2/metabolomics/GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz'

# %%
for page in pages:
    for obj in page.get('Contents', []):
        if obj['Key'].endswith('.mzML.gz'):
            s3_file_keys.append(obj['Key'])

print(f"Found {len(s3_file_keys)} total files to process.")
# Out:
# Found 133 total files to process.

# %%
first_key = s3_file_keys[0]
first_filename = os.path.basename(first_key)
local_first_filename = os.path.join(temp_dir, first_filename)

print(f"Downloading '{first_filename}' to inspect...")
s3_client.download_file(bucket_name, first_key, local_first_filename)

run_first_filename = pymzml.run.Reader(local_first_filename)
first_spectrum = next(iter(run_first_filename))

print(f"\nEach item from the 'run' object: {type(first_spectrum)}")

os.remove(local_first_filename)
# Out:
# Downloading 'GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz' to inspect...
#
# Each item from the 'run' object: <class 'pymzml.spec.Spectrum'>

# %%
total_files = len(s3_file_keys)
for x, key in enumerate(s3_file_keys):
    try:
        filename = os.path.basename(key)
        local_filepath = os.path.join(temp_dir, filename)

        percent_complete = ((x + 1) / total_files) * 100
        
        print(f"({x + 1}/{total_files}) [{percent_complete:.2f}%] Downloading {filename}...")
        s3_client.download_file(bucket_name, key, local_filepath)
        
        print(f"({x + 1}/{total_files}) [{percent_complete:.2f}%] Processing {filename}...")
        run = pymzml.run.Reader(local_filepath)
        
        if run:
            file_total_intensity = 0
            num_spectra = 0
            ms1_scans = 0
            ms2_scans = 0
            total_base_peak_intensity = 0.0
            total_peaks_in_file = 0
            for spectrum in run:
                file_total_intensity += sum(spectrum.i)
                num_spectra += 1
                if spectrum.ms_level == 1:
                    ms1_scans += 1
                elif spectrum.ms_level == 2:
                    ms2_scans += 1

                if len(spectrum.i) > 0:
                    i = np.max(spectrum.i)
                    total_base_peak_intensity += i

                total_peaks_in_file += len(spectrum.i)

            avg_peaks_per_scan = total_peaks_in_file / num_spectra if num_spectra > 0 else 0

            results.append({
                'filename': filename,
                'total_intensity': file_total_intensity,
                'tic_datapoints': num_spectra,
                'ms1_scans': ms1_scans,
                'ms2_scans': ms2_scans,
                'sum_base_peak_intensity': total_base_peak_intensity,
                'avg_peaks_per_scan': avg_peaks_per_scan
            })
            print(f"({x + 1}/{total_files}) [{percent_complete:.2f}%] Successfully processed {filename}.")

        else:
            print(f"Skipping: {filename} is empty or invalid")
        
        os.remove(local_filepath)
        print(f"Finished and cleaned up {filename}.")

    except Exception as e:
        print(f"Failed to process {key}: {e}")
# Out:
# (1/133) [0.75%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz...
# (1/133) [0.75%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz...
# (1/133) [0.75%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos1.mzML.gz.
# (2/133) [1.50%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos10.mzML.gz...
# (2/133) [1.50%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos10.mzML.gz...
# (2/133) [1.50%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos10.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos10.mzML.gz.
# (3/133) [2.26%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos11.mzML.gz...
# (3/133) [2.26%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos11.mzML.gz...
# (3/133) [2.26%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos11.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos11.mzML.gz.
# (4/133) [3.01%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos12.mzML.gz...
# (4/133) [3.01%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos12.mzML.gz...
# (4/133) [3.01%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos12.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos12.mzML.gz.
# (5/133) [3.76%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos13.mzML.gz...
# (5/133) [3.76%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos13.mzML.gz...
# (5/133) [3.76%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos13.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos13.mzML.gz.
# (6/133) [4.51%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos14.mzML.gz...
# (6/133) [4.51%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos14.mzML.gz...
# (6/133) [4.51%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos14.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos14.mzML.gz.
# (7/133) [5.26%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos15.mzML.gz...
# (7/133) [5.26%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos15.mzML.gz...
# (7/133) [5.26%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos15.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos15.mzML.gz.
# (8/133) [6.02%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos16.mzML.gz...
# (8/133) [6.02%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos16.mzML.gz...
# (8/133) [6.02%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos16.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos16.mzML.gz.
# (9/133) [6.77%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos17.mzML.gz...
# (9/133) [6.77%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos17.mzML.gz...
# (9/133) [6.77%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos17.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos17.mzML.gz.
# (10/133) [7.52%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos18.mzML.gz...
# (10/133) [7.52%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos18.mzML.gz...
# (10/133) [7.52%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos18.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos18.mzML.gz.
# (11/133) [8.27%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos19.mzML.gz...
# (11/133) [8.27%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos19.mzML.gz...
# (11/133) [8.27%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos19.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos19.mzML.gz.
# (12/133) [9.02%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos2.mzML.gz...
# (12/133) [9.02%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos2.mzML.gz...
# (12/133) [9.02%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos2.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos2.mzML.gz.
# (13/133) [9.77%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos20.mzML.gz...
# (13/133) [9.77%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos20.mzML.gz...
# (13/133) [9.77%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos20.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos20.mzML.gz.
# (14/133) [10.53%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos21.mzML.gz...
# (14/133) [10.53%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos21.mzML.gz...
# (14/133) [10.53%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos21.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos21.mzML.gz.
# (15/133) [11.28%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos22.mzML.gz...
# (15/133) [11.28%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos22.mzML.gz...
# (15/133) [11.28%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos22.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos22.mzML.gz.
# (16/133) [12.03%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos23.mzML.gz...
# (16/133) [12.03%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos23.mzML.gz...
# (16/133) [12.03%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos23.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos23.mzML.gz.
# (17/133) [12.78%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos24.mzML.gz...
# (17/133) [12.78%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos24.mzML.gz...
# (17/133) [12.78%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos24.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos24.mzML.gz.
# (18/133) [13.53%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos25.mzML.gz...
# (18/133) [13.53%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos25.mzML.gz...
# (18/133) [13.53%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos25.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos25.mzML.gz.
# (19/133) [14.29%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos26.mzML.gz...
# (19/133) [14.29%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos26.mzML.gz...
# (19/133) [14.29%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos26.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos26.mzML.gz.
# (20/133) [15.04%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos27.mzML.gz...
# (20/133) [15.04%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos27.mzML.gz...
# (20/133) [15.04%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos27.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos27.mzML.gz.
# (21/133) [15.79%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos28.mzML.gz...
# (21/133) [15.79%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos28.mzML.gz...
# (21/133) [15.79%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos28.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos28.mzML.gz.
# (22/133) [16.54%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos29.mzML.gz...
# (22/133) [16.54%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos29.mzML.gz...
# (22/133) [16.54%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos29.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos29.mzML.gz.
# (23/133) [17.29%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos3.mzML.gz...
# (23/133) [17.29%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos3.mzML.gz...
# (23/133) [17.29%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos3.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos3.mzML.gz.
# (24/133) [18.05%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos30.mzML.gz...
# (24/133) [18.05%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos30.mzML.gz...
# (24/133) [18.05%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos30.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos30.mzML.gz.
# (25/133) [18.80%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos31.mzML.gz...
# (25/133) [18.80%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos31.mzML.gz...
# (25/133) [18.80%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos31.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos31.mzML.gz.
# (26/133) [19.55%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos32.mzML.gz...
# (26/133) [19.55%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos32.mzML.gz...
# (26/133) [19.55%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos32.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos32.mzML.gz.
# (27/133) [20.30%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos33.mzML.gz...
# (27/133) [20.30%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos33.mzML.gz...
# (27/133) [20.30%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos33.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos33.mzML.gz.
# (28/133) [21.05%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos34.mzML.gz...
# (28/133) [21.05%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos34.mzML.gz...
# (28/133) [21.05%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos34.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos34.mzML.gz.
# (29/133) [21.80%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos35.mzML.gz...
# (29/133) [21.80%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos35.mzML.gz...
# (29/133) [21.80%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos35.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos35.mzML.gz.
# (30/133) [22.56%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos36.mzML.gz...
# (30/133) [22.56%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos36.mzML.gz...
# (30/133) [22.56%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos36.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos36.mzML.gz.
# (31/133) [23.31%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos37.mzML.gz...
# (31/133) [23.31%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos37.mzML.gz...
# (31/133) [23.31%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos37.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos37.mzML.gz.
# (32/133) [24.06%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos38.mzML.gz...
# (32/133) [24.06%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos38.mzML.gz...
# (32/133) [24.06%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos38.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos38.mzML.gz.
# (33/133) [24.81%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos39.mzML.gz...
# (33/133) [24.81%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos39.mzML.gz...
# (33/133) [24.81%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos39.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos39.mzML.gz.
# (34/133) [25.56%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos4.mzML.gz...
# (34/133) [25.56%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos4.mzML.gz...
# (34/133) [25.56%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos4.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos4.mzML.gz.
# (35/133) [26.32%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos40.mzML.gz...
# (35/133) [26.32%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos40.mzML.gz...
# (35/133) [26.32%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos40.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos40.mzML.gz.
# (36/133) [27.07%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos41.mzML.gz...
# (36/133) [27.07%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos41.mzML.gz...
# (36/133) [27.07%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos41.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos41.mzML.gz.
# (37/133) [27.82%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos42.mzML.gz...
# (37/133) [27.82%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos42.mzML.gz...
# (37/133) [27.82%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos42.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos42.mzML.gz.
# (38/133) [28.57%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos43.mzML.gz...
# (38/133) [28.57%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos43.mzML.gz...
# (38/133) [28.57%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos43.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos43.mzML.gz.
# (39/133) [29.32%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos44.mzML.gz...
# (39/133) [29.32%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos44.mzML.gz...
# (39/133) [29.32%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos44.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos44.mzML.gz.
# (40/133) [30.08%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos45.mzML.gz...
# (40/133) [30.08%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos45.mzML.gz...
# (40/133) [30.08%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos45.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos45.mzML.gz.
# (41/133) [30.83%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos46.mzML.gz...
# (41/133) [30.83%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos46.mzML.gz...
# (41/133) [30.83%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos46.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos46.mzML.gz.
# (42/133) [31.58%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos47.mzML.gz...
# (42/133) [31.58%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos47.mzML.gz...
# (42/133) [31.58%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos47.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos47.mzML.gz.
# (43/133) [32.33%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos48.mzML.gz...
# (43/133) [32.33%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos48.mzML.gz...
# (43/133) [32.33%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos48.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos48.mzML.gz.
# (44/133) [33.08%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos49.mzML.gz...
# (44/133) [33.08%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos49.mzML.gz...
# (44/133) [33.08%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos49.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos49.mzML.gz.
# (45/133) [33.83%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos5.mzML.gz...
# (45/133) [33.83%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos5.mzML.gz...
# (45/133) [33.83%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos5.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos5.mzML.gz.
# (46/133) [34.59%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos50.mzML.gz...
# (46/133) [34.59%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos50.mzML.gz...
# (46/133) [34.59%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos50.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos50.mzML.gz.
# (47/133) [35.34%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos51.mzML.gz...
# (47/133) [35.34%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos51.mzML.gz...
# (47/133) [35.34%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos51.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos51.mzML.gz.
# (48/133) [36.09%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos52.mzML.gz...
# (48/133) [36.09%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos52.mzML.gz...
# (48/133) [36.09%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos52.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos52.mzML.gz.
# (49/133) [36.84%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos53.mzML.gz...
# (49/133) [36.84%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos53.mzML.gz...
# (49/133) [36.84%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos53.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos53.mzML.gz.
# (50/133) [37.59%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos54.mzML.gz...
# (50/133) [37.59%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos54.mzML.gz...
# (50/133) [37.59%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos54.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos54.mzML.gz.
# (51/133) [38.35%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos55.mzML.gz...
# (51/133) [38.35%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos55.mzML.gz...
# (51/133) [38.35%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos55.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos55.mzML.gz.
# (52/133) [39.10%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos56.mzML.gz...
# (52/133) [39.10%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos56.mzML.gz...
# (52/133) [39.10%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos56.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos56.mzML.gz.
# (53/133) [39.85%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos57.mzML.gz...
# (53/133) [39.85%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos57.mzML.gz...
# (53/133) [39.85%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos57.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos57.mzML.gz.
# (54/133) [40.60%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos58.mzML.gz...
# (54/133) [40.60%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos58.mzML.gz...
# (54/133) [40.60%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos58.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos58.mzML.gz.
# (55/133) [41.35%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos59.mzML.gz...
# (55/133) [41.35%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos59.mzML.gz...
# (55/133) [41.35%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos59.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos59.mzML.gz.
# (56/133) [42.11%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos6.mzML.gz...
# (56/133) [42.11%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos6.mzML.gz...
# (56/133) [42.11%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos6.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos6.mzML.gz.
# (57/133) [42.86%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos60.mzML.gz...
# (57/133) [42.86%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos60.mzML.gz...
# (57/133) [42.86%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos60.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos60.mzML.gz.
# (58/133) [43.61%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos61.mzML.gz...
# (58/133) [43.61%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos61.mzML.gz...
# (58/133) [43.61%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos61.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos61.mzML.gz.
# (59/133) [44.36%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos62.mzML.gz...
# (59/133) [44.36%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos62.mzML.gz...
# (59/133) [44.36%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos62.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos62.mzML.gz.
# (60/133) [45.11%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos63.mzML.gz...
# (60/133) [45.11%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos63.mzML.gz...
# (60/133) [45.11%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos63.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos63.mzML.gz.
# (61/133) [45.86%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos64.mzML.gz...
# (61/133) [45.86%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos64.mzML.gz...
# (61/133) [45.86%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos64.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos64.mzML.gz.
# (62/133) [46.62%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos65.mzML.gz...
# (62/133) [46.62%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos65.mzML.gz...
# (62/133) [46.62%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos65.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos65.mzML.gz.
# (63/133) [47.37%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos66.mzML.gz...
# (63/133) [47.37%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos66.mzML.gz...
# (63/133) [47.37%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos66.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos66.mzML.gz.
# (64/133) [48.12%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos67.mzML.gz...
# (64/133) [48.12%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos67.mzML.gz...
# (64/133) [48.12%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos67.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos67.mzML.gz.
# (65/133) [48.87%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos7.mzML.gz...
# (65/133) [48.87%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos7.mzML.gz...
# (65/133) [48.87%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos7.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos7.mzML.gz.
# (66/133) [49.62%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos8.mzML.gz...
# (66/133) [49.62%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos8.mzML.gz...
# (66/133) [49.62%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos8.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos8.mzML.gz.
# (67/133) [50.38%] Downloading GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos9.mzML.gz...
# (67/133) [50.38%] Processing GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos9.mzML.gz...
# (67/133) [50.38%] Successfully processed GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos9.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_082120_Marek_Raber_Plasma_pos9.mzML.gz.
# (68/133) [51.13%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative1.mzML.gz...
# (68/133) [51.13%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative1.mzML.gz...
# (68/133) [51.13%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative1.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative1.mzML.gz.
# (69/133) [51.88%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative10.mzML.gz...
# (69/133) [51.88%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative10.mzML.gz...
# (69/133) [51.88%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative10.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative10.mzML.gz.
# (70/133) [52.63%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative11.mzML.gz...
# (70/133) [52.63%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative11.mzML.gz...
# (70/133) [52.63%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative11.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative11.mzML.gz.
# (71/133) [53.38%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative12.mzML.gz...
# (71/133) [53.38%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative12.mzML.gz...
# (71/133) [53.38%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative12.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative12.mzML.gz.
# (72/133) [54.14%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative13.mzML.gz...
# (72/133) [54.14%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative13.mzML.gz...
# (72/133) [54.14%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative13.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative13.mzML.gz.
# (73/133) [54.89%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative14.mzML.gz...
# (73/133) [54.89%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative14.mzML.gz...
# (73/133) [54.89%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative14.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative14.mzML.gz.
# (74/133) [55.64%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative15.mzML.gz...
# (74/133) [55.64%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative15.mzML.gz...
# (74/133) [55.64%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative15.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative15.mzML.gz.
# (75/133) [56.39%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative16.mzML.gz...
# (75/133) [56.39%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative16.mzML.gz...
# (75/133) [56.39%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative16.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative16.mzML.gz.
# (76/133) [57.14%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative17.mzML.gz...
# (76/133) [57.14%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative17.mzML.gz...
# (76/133) [57.14%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative17.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative17.mzML.gz.
# (77/133) [57.89%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative18.mzML.gz...
# (77/133) [57.89%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative18.mzML.gz...
# (77/133) [57.89%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative18.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative18.mzML.gz.
# (78/133) [58.65%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative19.mzML.gz...
# (78/133) [58.65%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative19.mzML.gz...
# (78/133) [58.65%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative19.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative19.mzML.gz.
# (79/133) [59.40%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative2.mzML.gz...
# (79/133) [59.40%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative2.mzML.gz...
# (79/133) [59.40%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative2.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative2.mzML.gz.
# (80/133) [60.15%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative20.mzML.gz...
# (80/133) [60.15%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative20.mzML.gz...
# (80/133) [60.15%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative20.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative20.mzML.gz.
# (81/133) [60.90%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative21.mzML.gz...
# (81/133) [60.90%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative21.mzML.gz...
# (81/133) [60.90%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative21.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative21.mzML.gz.
# (82/133) [61.65%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative22.mzML.gz...
# (82/133) [61.65%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative22.mzML.gz...
# (82/133) [61.65%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative22.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative22.mzML.gz.
# (83/133) [62.41%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative23.mzML.gz...
# (83/133) [62.41%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative23.mzML.gz...
# (83/133) [62.41%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative23.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative23.mzML.gz.
# (84/133) [63.16%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative24.mzML.gz...
# (84/133) [63.16%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative24.mzML.gz...
# (84/133) [63.16%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative24.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative24.mzML.gz.
# (85/133) [63.91%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative25.mzML.gz...
# (85/133) [63.91%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative25.mzML.gz...
# (85/133) [63.91%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative25.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative25.mzML.gz.
# (86/133) [64.66%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative26.mzML.gz...
# (86/133) [64.66%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative26.mzML.gz...
# (86/133) [64.66%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative26.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative26.mzML.gz.
# (87/133) [65.41%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative27.mzML.gz...
# (87/133) [65.41%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative27.mzML.gz...
# (87/133) [65.41%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative27.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative27.mzML.gz.
# (88/133) [66.17%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative28.mzML.gz...
# (88/133) [66.17%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative28.mzML.gz...
# (88/133) [66.17%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative28.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative28.mzML.gz.
# (89/133) [66.92%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative29.mzML.gz...
# (89/133) [66.92%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative29.mzML.gz...
# (89/133) [66.92%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative29.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative29.mzML.gz.
# (90/133) [67.67%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative30.mzML.gz...
# (90/133) [67.67%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative30.mzML.gz...
# (90/133) [67.67%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative30.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative30.mzML.gz.
# (91/133) [68.42%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative31.mzML.gz...
# (91/133) [68.42%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative31.mzML.gz...
# (91/133) [68.42%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative31.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative31.mzML.gz.
# (92/133) [69.17%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative32.mzML.gz...
# (92/133) [69.17%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative32.mzML.gz...
# (92/133) [69.17%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative32.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative32.mzML.gz.
# (93/133) [69.92%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative33.mzML.gz...
# (93/133) [69.92%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative33.mzML.gz...
# (93/133) [69.92%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative33.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative33.mzML.gz.
# (94/133) [70.68%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative34.mzML.gz...
# (94/133) [70.68%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative34.mzML.gz...
# (94/133) [70.68%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative34.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative34.mzML.gz.
# (95/133) [71.43%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative35.mzML.gz...
# (95/133) [71.43%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative35.mzML.gz...
# (95/133) [71.43%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative35.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative35.mzML.gz.
# (96/133) [72.18%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative36.mzML.gz...
# (96/133) [72.18%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative36.mzML.gz...
# (96/133) [72.18%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative36.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative36.mzML.gz.
# (97/133) [72.93%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative37.mzML.gz...
# (97/133) [72.93%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative37.mzML.gz...
# (97/133) [72.93%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative37.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative37.mzML.gz.
# (98/133) [73.68%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative38.mzML.gz...
# (98/133) [73.68%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative38.mzML.gz...
# (98/133) [73.68%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative38.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative38.mzML.gz.
# (99/133) [74.44%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative39.mzML.gz...
# (99/133) [74.44%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative39.mzML.gz...
# (99/133) [74.44%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative39.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative39.mzML.gz.
# (100/133) [75.19%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative4.mzML.gz...
# (100/133) [75.19%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative4.mzML.gz...
# (100/133) [75.19%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative4.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative4.mzML.gz.
# (101/133) [75.94%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative40.mzML.gz...
# (101/133) [75.94%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative40.mzML.gz...
# (101/133) [75.94%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative40.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative40.mzML.gz.
# (102/133) [76.69%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative41.mzML.gz...
# (102/133) [76.69%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative41.mzML.gz...
# (102/133) [76.69%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative41.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative41.mzML.gz.
# (103/133) [77.44%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative42.mzML.gz...
# (103/133) [77.44%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative42.mzML.gz...
# (103/133) [77.44%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative42.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative42.mzML.gz.
# (104/133) [78.20%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative43.mzML.gz...
# (104/133) [78.20%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative43.mzML.gz...
# (104/133) [78.20%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative43.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative43.mzML.gz.
# (105/133) [78.95%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative44.mzML.gz...
# (105/133) [78.95%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative44.mzML.gz...
# (105/133) [78.95%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative44.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative44.mzML.gz.
# (106/133) [79.70%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative45.mzML.gz...
# (106/133) [79.70%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative45.mzML.gz...
# (106/133) [79.70%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative45.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative45.mzML.gz.
# (107/133) [80.45%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative46.mzML.gz...
# (107/133) [80.45%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative46.mzML.gz...
# (107/133) [80.45%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative46.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative46.mzML.gz.
# (108/133) [81.20%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative47.mzML.gz...
# (108/133) [81.20%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative47.mzML.gz...
# (108/133) [81.20%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative47.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative47.mzML.gz.
# (109/133) [81.95%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative48.mzML.gz...
# (109/133) [81.95%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative48.mzML.gz...
# (109/133) [81.95%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative48.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative48.mzML.gz.
# (110/133) [82.71%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative49.mzML.gz...
# (110/133) [82.71%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative49.mzML.gz...
# (110/133) [82.71%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative49.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative49.mzML.gz.
# (111/133) [83.46%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative5.mzML.gz...
# (111/133) [83.46%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative5.mzML.gz...
# (111/133) [83.46%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative5.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative5.mzML.gz.
# (112/133) [84.21%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative50.mzML.gz...
# (112/133) [84.21%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative50.mzML.gz...
# (112/133) [84.21%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative50.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative50.mzML.gz.
# (113/133) [84.96%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative51.mzML.gz...
# (113/133) [84.96%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative51.mzML.gz...
# (113/133) [84.96%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative51.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative51.mzML.gz.
# (114/133) [85.71%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative52.mzML.gz...
# (114/133) [85.71%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative52.mzML.gz...
# (114/133) [85.71%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative52.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative52.mzML.gz.
# (115/133) [86.47%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative53.mzML.gz...
# (115/133) [86.47%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative53.mzML.gz...
# (115/133) [86.47%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative53.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative53.mzML.gz.
# (116/133) [87.22%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative54.mzML.gz...
# (116/133) [87.22%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative54.mzML.gz...
# (116/133) [87.22%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative54.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative54.mzML.gz.
# (117/133) [87.97%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative55.mzML.gz...
# (117/133) [87.97%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative55.mzML.gz...
# (117/133) [87.97%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative55.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative55.mzML.gz.
# (118/133) [88.72%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative56.mzML.gz...
# (118/133) [88.72%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative56.mzML.gz...
# (118/133) [88.72%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative56.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative56.mzML.gz.
# (119/133) [89.47%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative57.mzML.gz...
# (119/133) [89.47%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative57.mzML.gz...
# (119/133) [89.47%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative57.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative57.mzML.gz.
# (120/133) [90.23%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative58.mzML.gz...
# (120/133) [90.23%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative58.mzML.gz...
# (120/133) [90.23%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative58.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative58.mzML.gz.
# (121/133) [90.98%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative59.mzML.gz...
# (121/133) [90.98%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative59.mzML.gz...
# (121/133) [90.98%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative59.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative59.mzML.gz.
# (122/133) [91.73%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative6.mzML.gz...
# (122/133) [91.73%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative6.mzML.gz...
# (122/133) [91.73%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative6.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative6.mzML.gz.
# (123/133) [92.48%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative60.mzML.gz...
# (123/133) [92.48%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative60.mzML.gz...
# (123/133) [92.48%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative60.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative60.mzML.gz.
# (124/133) [93.23%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative61.mzML.gz...
# (124/133) [93.23%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative61.mzML.gz...
# (124/133) [93.23%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative61.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative61.mzML.gz.
# (125/133) [93.98%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative62.mzML.gz...
# (125/133) [93.98%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative62.mzML.gz...
# (125/133) [93.98%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative62.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative62.mzML.gz.
# (126/133) [94.74%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative63.mzML.gz...
# (126/133) [94.74%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative63.mzML.gz...
# (126/133) [94.74%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative63.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative63.mzML.gz.
# (127/133) [95.49%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative64.mzML.gz...
# (127/133) [95.49%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative64.mzML.gz...
# (127/133) [95.49%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative64.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative64.mzML.gz.
# (128/133) [96.24%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative65.mzML.gz...
# (128/133) [96.24%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative65.mzML.gz...
# (128/133) [96.24%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative65.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative65.mzML.gz.
# (129/133) [96.99%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative66.mzML.gz...
# (129/133) [96.99%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative66.mzML.gz...
# (129/133) [96.99%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative66.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative66.mzML.gz.
# (130/133) [97.74%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative67.mzML.gz...
# (130/133) [97.74%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative67.mzML.gz...
# (130/133) [97.74%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative67.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative67.mzML.gz.
# (131/133) [98.50%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative7.mzML.gz...
# (131/133) [98.50%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative7.mzML.gz...
# (131/133) [98.50%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative7.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative7.mzML.gz.
# (132/133) [99.25%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative8.mzML.gz...
# (132/133) [99.25%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative8.mzML.gz...
# (132/133) [99.25%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative8.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative8.mzML.gz.
# (133/133) [100.00%] Downloading GLDS-703_metabolomics_091920_Raber_Marek_Negative9.mzML.gz...
# (133/133) [100.00%] Processing GLDS-703_metabolomics_091920_Raber_Marek_Negative9.mzML.gz...
# (133/133) [100.00%] Successfully processed GLDS-703_metabolomics_091920_Raber_Marek_Negative9.mzML.gz.
# Finished and cleaned up GLDS-703_metabolomics_091920_Raber_Marek_Negative9.mzML.gz.

# %%
df_features = pd.DataFrame(results)

print("\nDataFrame with features:")
display(df_features)
# Out:
# DataFrame with features:
#                                               filename  total_intensity  \
# 0    GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.368131e+10
# 1    GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.155506e+10
# 2    GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.153483e+10
# 3    GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.143695e+10
# 4    GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.122497e+10
# ..                                                 ...              ...
# 128  GLDS-703_metabolomics_091920_Raber_Marek_Negat...     5.110776e+09
# 129  GLDS-703_metabolomics_091920_Raber_Marek_Negat...     7.086478e+09
# 130  GLDS-703_metabolomics_091920_Raber_Marek_Negat...     6.737794e+09
# 131  GLDS-703_metabolomics_091920_Raber_Marek_Negat...     7.099848e+09
# 132  GLDS-703_metabolomics_091920_Raber_Marek_Negat...     6.680649e+09
#
#      tic_datapoints  ms1_scans  ms2_scans  sum_base_peak_intensity  \
# 0             17540       2973      14567              323813056.0
# 1             16563       3038      13525              342596704.0
# 2             16677       3030      13647              341492416.0
# 3             16571       3034      13537              343744672.0
# 4             16879       3038      13841              319452896.0
# ..              ...        ...        ...                      ...
# 128           18423       3797      14626               46674604.0
# 129           18638       3813      14825              143802784.0
# 130           18523       3807      14716              144499936.0
# 131           18527       3800      14727              220994080.0
# 132           18528       3802      14726              136528864.0
#
#      avg_peaks_per_scan
# 0           6566.761345
# 1           4973.952364
# 2           4930.622354
# 3           4910.967473
# 4           4832.251377
# ..                  ...
# 128        14070.876296
# 129        13582.883786
# 130        13510.817200
# 131        13497.215469
# 132        13534.522938
#
# [133 rows x 7 columns]

# %%
df_final = pd.merge(df_features, df_combined, left_on='filename', right_on='Parameter Value[Raw Spectral Data File (mzML)]', how='left')

print("Final Merged DataFrame:")
display(df_final.head())
# Out:
# Final Merged DataFrame:
#                                             filename  total_intensity  \
# 0  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.368131e+10
# 1  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.155506e+10
# 2  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.153483e+10
# 3  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.143695e+10
# 4  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...     1.122497e+10
#
#    tic_datapoints  ms1_scans  ms2_scans  sum_base_peak_intensity  \
# 0           17540       2973      14567              323813056.0
# 1           16563       3038      13525              342596704.0
# 2           16677       3030      13647              341492416.0
# 3           16571       3034      13537              343744672.0
# 4           16879       3038      13841              319452896.0
#
#    avg_peaks_per_scan  Sample Name  \
# 0         6566.761345     QC Blank
# 1         4973.952364  9429 plasma
# 2         4930.622354  9447 plasma
# 3         4910.967473  9398 plasma
# 4         4832.251377  9442 plasma
#
#       Parameter Value[Raw Spectral Data File (mzML)]  \
# 0  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 1  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 2  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 3  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
# 4  GLDS-703_metabolomics_082120_Marek_Raber_Plasm...
#
#   Factor Value[Ionizing Radiation] Factor Value[Hindlimb Unloading]
# 0                   Not Applicable                   Not Applicable
# 1            mixed radiation field                Hindlimb Unloaded
# 2            mixed radiation field          Normally Loaded Control
# 3                  sham-irradiated          Normally Loaded Control
# 4            mixed radiation field          Normally Loaded Control

# %%
codespace_path = 'data/cleaned_data/OSD-832_final_processed_data.parquet'

os.makedirs(os.path.dirname(codespace_path), exist_ok=True)

df_final.to_parquet(codespace_path, engine='fastparquet')
